# %% [markdown]
# # <div style="text-align: center;"> <span style="color: #1C6BA0; font-weight: bold;">Data Cleaning And Exploratory Data Analysis On Titanic Dataset</span> </div>

# %% [markdown]
# ##
# ---
# **Name** : **ANJALI J**
#
# **Company** : **Prodigy InfoTech**
#
# **Task 2**
#
# ---

# %% [markdown]
# ## <span style="color:#00CED1"><strong>Problem Statement</strong></span>

# %% [markdown]
# ## **Perform data cleaning and exploratory data analysis (EDA) on Titanic dataset from Kaggle. Explore the relationships between variables and identify patterns and trends in the data.**

# %% [markdown]
# ## <span style="color:#00CED1"><strong>About the dataset</strong></span>

# %% [markdown]
# #### The Titanic dataset is a popular dataset in machine learning and data analysis, often used for binary classification tasks such as predicting survival on the Titanic. It contains information about passengers aboard the RMS Titanic, which sank in 1912. The dataset provides a mix of categorical and numerical features.

# %% [markdown]
# ## <span style="color:#00CED1"><strong>Importing required libraries</strong></span>

# %%
import warnings
warnings.simplefilter("ignore")
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %% [markdown]
# ## <span style="color:#00CED1"><strong>Loading the dataset</strong></span>

# %%
df=pd.read_csv("titanic_dataset.csv")
df
# Out:
#       Passenger_Id  Survived  Pclass  \
# 0                1         0       3
# 1                2         1       1
# 2                3         1       3
# 3                4         1       1
# 4                5         0       3
# ...            ...       ...     ...
# 1304          1305         0       3
# 1305          1306         1       1
# 1306          1307         0       3
# 1307          1308         0       3
# 1308          1309         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ## <span style="color:#00CED1"><strong>Data Description</strong></span>

# %% [markdown]
# ---
# #### <span style="color:red"><strong>Source</strong></span> : [Click Here](https://www.canva.com/link?target=https%3A%2F%2Fwww.kaggle.com%2Fc%2Ftitanic%2Fdata&design=DAFpRxy47kU&accessRole=viewer&linkSource=document)
#
# ---
#
# Here is a description of each column in the population dataset :
# * **PassengerId** : Unique identifier for each passenger (integer).
# * **Survived** : Binary indicator of survival status:
#
#     0 = Did not survive
#
#     1 = Survived
#
# * **Pclass** : Ticket class, a proxy for socioeconomic status (integer):
#
#     1 = First class (upper class)
#
#     2 = Second class (middle class)
#
#     3 = Third class (lower class)
#
# * **Name** : Full name of the passenger (string).
# * **Sex** : Gender of the passenger (male or female).
# * **Age** : Age of the passenger in years (float; can have missing values).
# * **SibSp** : Number of siblings or spouses aboard the Titanic (integer).
# * **Parch** : Number of parents or children aboard the Titanic (integer).
# * **Ticket** : Ticket number (string).
# * **Fare** : Passenger fare (float).
# * **Cabin** : Cabin number (string; often has missing values).
# * **Embarked** : Port of embarkation (categorical):
#
#     C = Cherbourg
#
#     Q = Queenstown
#
#     S = Southampton

# %% [markdown]
# ## <span style="color:#00CED1"><strong>Overview of the dataset</strong></span>

# %%
df.shape
# Out:
# (1309, 12)

# %% [markdown]
# #### Dataset contains 1309 rows and 12 columns.

# %%
df.head()
# Out:
#    Passenger_Id  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        Passenger_Id     Survived       Pclass          Age        SibSp  \
# count   1309.000000  1309.000000  1309.000000  1046.000000  1309.000000
# mean     655.000000     0.377387     2.294882    29.881138     0.498854
# std      378.020061     0.484918     0.837836    14.413493     1.041658
# min        1.000000     0.000000     1.000000     0.170000     0.000000
# 25%      328.000000     0.000000     2.000000    21.000000     0.000000
# 50%      655.000000     0.000000     3.000000    28.000000     0.000000
# 75%      982.000000     1.000000     3.000000    39.000000     1.000000
# max     1309.000000     1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Passenger_Id  1309 non-null   int64
#  1   Survived      1309 non-null   int64
#  2   Pclass        1309 non-null   int64
#  3   Name          1309 non-null   object
#  4   Sex           1309 non-null   object
#  5   Age           1046 non-null   float64
#  6   SibSp         1309 non-null   int64
#  7   Parch         1309 non-null   int64
#  8   Ticket        1309 non-null   object
#  9   Fare          1308 non-null   float64
#  10  Cabin         295 non-null    object
#  11  Embarked      1307 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# #### There are missing values in some columns.

# %%
df.columns
# Out:
# Index(['Passenger_Id', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## <span style="color:#00CED1"><strong>Data Cleaning</strong></span>

# %% [markdown]
# ### **Finding missing values**

# %%
missing_values = df.isnull().sum()

print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# Passenger_Id       0
# Survived           0
# Pclass             0
# Name               0
# Sex                0
# Age              263
# SibSp              0
# Parch              0
# Ticket             0
# Fare               1
# Cabin           1014
# Embarked           2
# dtype: int64

# %% [markdown]
# #### There are **263** missing values in **Age** column, **1014** missing values in **Cabin** column, **1** missing value in **Fare** column and **2** missing values in **Embarked** column.

# %% [markdown]
# ### **Handling Missing Values**

# %% [markdown]
# #### We can replace missing values in **Age** column by **median**. Most of the values in **Cabin** column are NaN values. So, this column can be removed. Rest of the missing values can be dropped.

# %%
# Replace missing values in the 'Age' column with the median
df['Age'].fillna(df['Age'].median(), inplace=True)

# Delete the 'Cabin' column
df.drop(columns='Cabin', inplace=True)

# Drop rows with missing values in any other columns
df.dropna(inplace=True)

# Verify no missing values remain
print("Missing values after cleaning:")
print(df.isnull().sum())
# Out:
# Missing values after cleaning:
# Passenger_Id    0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        0
# dtype: int64

# %% [markdown]
# #### All the missing values are removed.

# %% [markdown]
# ### **Dropping Irrelevant columns**

# %% [markdown]
# #### Passenger_Id is an irrelevant column. It can be removed.

# %%
df.drop(columns='Passenger_Id', inplace=True)

# %%
df.shape
# Out:
# (1306, 10)

# %% [markdown]
# #### Now we have 1306 rows and 10 columns.

# %% [markdown]
# ### **Data Manipulation**

# %% [markdown]
# #### Replace 0 with 'No' and 1 with 'Yes' in the 'Survived' column

# %%
df['Survived'] = df['Survived'].replace({0: 'No', 1: 'Yes'})
df.head()
# Out:
#   Survived  Pclass                                               Name     Sex  \
# 0       No       3                            Braund, Mr. Owen Harris    male
# 1      Yes       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2      Yes       3                             Heikkinen, Miss. Laina  female
# 3      Yes       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4       No       3                           Allen, Mr. William Henry    male
#
#     Age  SibSp  Parch            Ticket     Fare Embarked
# 0  22.0      1      0         A/5 21171   7.2500        S
# 1  38.0      1      0          PC 17599  71.2833        C
# 2  26.0      0      0  STON/O2. 3101282   7.9250        S
# 3  35.0      1      0            113803  53.1000        S
# 4  35.0      0      0            373450   8.0500        S

# %% [markdown]
# ## <span style="color:#00CED1"><strong>Exploratory Data Analysis (EDA)</strong></span>

# %% [markdown]
# ### **Distribution of numerical variables**

# %%
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
numerical_columns
# Out:
# Index(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# Create subplots with a grid layout
num_cols = 2  # Number of columns in the grid
num_rows = (len(numerical_columns) + num_cols - 1) // num_cols  # Calculate required rows

fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 4 * num_rows))
axes = axes.flatten()  # Flatten axes for easy indexing

for i, col in enumerate(numerical_columns):
    sns.histplot(df[col], kde=True, ax=axes[i])
    axes[i].set_title(f"Distribution of {col}")

# Remove unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Insights** :
# * Most of the passengers have taken 3rd class ticket.
# * Most of the passengers are aged between 20 years and 40 years.
# * Most of the passengers are not travelling with either their siblings or spouses.
# * Most of the passengers are not travelling with either their parents or children.
# * Most of the passengers are travelling with a fare ranging from 0 to 25.

# %% [markdown]
# ### **Distribution of categorical variables**

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# Index(['Survived', 'Name', 'Sex', 'Ticket', 'Embarked'], dtype='object')

# %%
#  Define columns to plot
columns_to_plot = ['Sex', 'Embarked', 'Survived']

# Create subplots
fig, axes = plt.subplots(1, len(columns_to_plot), figsize=(15, 5))

custom_palettes = ['Reds', 'Greens', 'Oranges']

for i, col in enumerate(columns_to_plot):
    sns.countplot(x=col, data=df, ax=axes[i], palette=custom_palettes[i])
    axes[i].set_title(f"Count Plot of {col}")
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Insights** :
# * Most of the passengers are males. More than 800 passengers are males and around 450 passengers are females.
# * Port of embarkation are Cherbourg (C), Queenstown (Q), Southampton (S). Most of the passengers started their journey from Southampton.
# * Number of passengers survived is less than number of passengers died. More than 800 passengers have died. Only around 500 passengers survived.

# %% [markdown]
# ### **Survival by Gender**

# %%
# Set color palette manually
colors = ['#9b59b6', '#f1c40f']  # Blue for 'Male', Red for 'Female'
sns.set_palette(sns.color_palette(colors))

# Count plot
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title("Survival Counts by Gender")
plt.ylabel("Count")
plt.xlabel("Gender")
plt.legend(title="Survived", labels=["No", "Yes"])
plt.show()

# %% [markdown]
# #### **Insights** :
# * Around 750 males have died and around 100 males have survived.
# * Less than 100 females have died and around 400 females have survived.

# %% [markdown]
# ### **Survival By Class**

# %%
sns.barplot(x='Pclass', y='Survived', data=df, color='#ff69b4')
plt.title("Survival by Passenger Class")
plt.show()

# %% [markdown]
# #### **Insights** :
# Passengers who chose 1st and 2nd class have more survival rate.

# %% [markdown]
# ### **Fare Analysis**

# %%
sns.boxplot(x='Pclass', y='Fare', data=df, color='red')
plt.title("Fare Distribution by Class")
plt.show()

# %% [markdown]
# #### **Insights** :
# * By comparing the medians of the different Pclass categories (1, 2, and 3), we can infer that first-class passengers (Pclass = 1) tend to have a higher median fare compared to second-class and third-class passengers.
# * The dots or points outside the whiskers are considered outliers. These represent fares that are significantly higher or lower than the rest of the data in that class.
# * By comparing the whiskers of different classes, we can see how far the highest and lowest fares extend for each class.
# * First-class passengers tend to pay significantly higher fares on average. Third-class fares are more tightly clustered around the lower end of the fare range.

# %% [markdown]
# ### **Age Analysis**

# %%
sns.histplot(df['Age'].dropna(), kde=True, color='orange')
plt.title("Age Distribution")
plt.show()

sns.boxplot(x='Survived', y='Age', data=df, color='brown')
plt.title("Survival by Age")
plt.show()

# %% [markdown]
# #### **Insights** :
# * Most of the passengers are aged between 20 years and 40 years.
# * There are many outliers which we can see from the box plot. Median age of survived and died passengers are almost same.

# %% [markdown]
# ### **Correlation matrix**

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df[numerical_columns].corr(),annot=True, linecolor= 'black')
plt.title("Heatmap of Correlation matrix")
plt.show()

# %% [markdown]
# #### **Insights** :
#  Pclass and Fare have a negative correlation. higher classes (Pclass = 1) tend to have higher fares, while lower classes (Pclass = 3) tend to have lower fares. So, the correlation between Pclass and Fare might be negative.

# %% [markdown]
# ### **Handling Outliers**

# %% [markdown]
# #### **Box plot for numerical columns**

# %%
sns.set(style="whitegrid")

# Create boxplots for each numerical column
plt.figure(figsize=(10, 7))  
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(3, 2, i)  
    sns.boxplot(x=df[column], color='orange')
    plt.title(f'Boxplot of {column}', fontsize=14)
    plt.xlabel(column, fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Detecting Outliers**

# %%
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[column] < lower_bound) | (data[column] > upper_bound)]

# %%
numerical_columns
# Out:
# Index(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
outliers_dict = {}

for column in numerical_columns:
    outliers = detect_outliers_iqr(df, column)
    outliers_dict[column] = outliers
    print(f"Outliers in {column}:")
    print(outliers)
    print(f"Number of outliers in {column}: {len(outliers)}\n")
# Out:
# Outliers in Pclass:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []
# Number of outliers in Pclass: 0
#
# Outliers in Age:
#      Survived  Pclass                                               Name  \
# 7          No       3                     Palsson, Master. Gosta Leonard
# 11        Yes       1                           Bonnell, Miss. Elizabeth
# 15        Yes       2                   Hewlett, Mrs. (Mary D Kingcome)
# 16         No       3                               Rice, Master. Eugene
# 33         No       2                              Wheadon, Mr. Edward H
# ...       ...     ...                                                ...
# 1234      Yes       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 1245      Yes       3            Dean, Miss. Elizabeth Gladys Millvina""
# 1247      Yes       1     Brown, Mrs. John Murray (Caroline Lane Lamson)
# ...

# %% [markdown]
# #### **Outlier removal using IQR method**

# %%
# Function to remove outliers using IQR
def remove_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

# Remove outliers for multiple columns
for column in numerical_columns:
    df1 = remove_outliers_iqr(df, column)

# Check the shape of the dataset after outlier removal
print(f"Dataset shape after outlier removal: {df1.shape}")
# Out:
# Dataset shape after outlier removal: (1137, 10)

# %% [markdown]
# #### **Box plot of  umerical columns after outlier removal**

# %%
sns.set(style="whitegrid")

# Create boxplots for each numerical column
plt.figure(figsize=(10, 7))  
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(3, 2, i)  
    sns.boxplot(x=df1[column], color='violet')
    plt.title(f'Boxplot of {column}', fontsize=14)
    plt.xlabel(column, fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Some outliers are removed. Outliers may contain useful information like VIP passengers with high fares. So, some outliers may be relevant for the dataset. Hence, all outliers cannot be removed.
